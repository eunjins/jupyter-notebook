# %%
pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'C:\Users\Eunjin'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np

# %%
n = pd.read_csv('C:/Users/Eunjin Shin/Desktop/jupyter-notebook/test/jetson_nano.csv')
x = pd.read_csv('C:/Users/Eunjin Shin/Desktop/jupyter-notebook/test/jetson_xavier_nx.csv')

# %%
n
# Out:
#    GoogLeNet  Inception V2  SSD MobileNet V2  ResNet 50  Tiny YOLO V3  \
# 0         81            56                36         36            34
#
#    Inception V3  UNet  Super Resolution  OpenPose  ResNet 152 V2  \
# 0            21    15                15        14             11
#
#    Inception V4  VGG 19
# 0            10      10

# %%
x
# Out:
#    SSD MobileNet V2  ResNet 50  Tiny YOLO V3  UNet  Super Resolution  \
# 0               899        969           586   144               159
#
#    OpenPose  Inception V4  VGG 19
# 0       236           318      66

# %%
pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'C:\Users\Eunjin'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter
# %matplotlib inline

# %% [markdown]
# fig = plt.figure(figsize=(15,10))
# ax = fig.add_subplot(111)
# cax = ax.matshow(df.corr(), vmin=-1, vmax=1, interpolation='none', cmap='bwr')
# fig.colorbar(cax)
# ticks = np.arange(0,12,1)
# ax.set_xticks(ticks)
# ax.set_yticks(ticks)
# ax.set_xticklabels(data)
# ax.set_yticklabels(data)
# plt.show()

# %%
n.plot(kind="bar")
plt.show()

# %%
x.plot(kind="bar")
plt.show()

# %% [markdown]
# **jeson nano와 jetson xavier nx 비교**
#
# **cnn을 파라미터 수에 따라 비교**
